# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathanbaray128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/El_profe_Act_13_Area_y_perimetro_Jonathan_Baray_0020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Jonathan Baray NL = 06  Fecha 25/Mar/2026 💓
# ---
# # Calcular Area y perimetro de un circulo
# ---
#
#  ![Fórmulas para calcular la circunferencia](https://matematix.org/wp-content/uploads/cuales-son-las-formulas-para-calcular-la-circunferencia.jpg)
#
#
# ---
# ## Formula para calcular area
# $A=\pi*r^2$
# ---
# ## Formula para calcular el perimetro
# $p=2*\pi*r$
# ---
# ## Datos de entrada
# $r$ ?
# ---
# ## Diagrama de flujo en LuciChart
# ![Logo de Mardown](https://raw.githubusercontent.com/jonathanbaray128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/Area_perimetro_circulo.png)

# %%
# calcular area y perimetro de un circulo
# variables A,P, r
# formulas A = pi*r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor de radio: "))
A = math.pi *r**2
P = 2*math.pi*r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Jonathan Baray NL = 06")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor de radio: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Jonathan Baray NL = 06

# %% [markdown]
# # Relacion entre codigo y DF en TIdraw
# ![logo Markdown](https://raw.githubusercontent.com/jonathanbaray128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20area%20y%20perimetro%20del%20circulo.PNG)
